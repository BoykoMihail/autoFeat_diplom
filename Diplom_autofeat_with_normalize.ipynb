# %%
import warnings
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Ridge
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression

from autofeat import AutoFeatRegressor

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
dataset = pd.read_csv('/Users/mikhailboyko/Projects/StudentsWork/DIPLOM/Dataset/Training/Features_Variant_1.csv')
datasetTest = pd.read_csv('/Users/mikhailboyko/Projects/StudentsWork/DIPLOM/Dataset/Training/Features_Variant_2.csv')

# %%
feateng_steps=2
X_train = preprocessing.normalize(dataset.iloc[:,:-1].to_numpy())
y_train = dataset.iloc[:,-1].to_numpy()

X_test = preprocessing.normalize(datasetTest.iloc[:,:-1].to_numpy())
y_test = datasetTest.iloc[:,-1].to_numpy()

# run autofeat
afreg = AutoFeatRegressor(verbose=1, feateng_steps=feateng_steps)
X_train_tr = afreg.fit_transform(X_train, y_train)
X_test_tr = afreg.transform(X_test)
print("######## Ridge Regression without autofeat")
rreg = Ridge()
param_grid = {"alpha": [0.00001, 0.0001, 0.001, 0.01, 0.1, 1., 2.5, 5., 10., 25., 50., 100., 250., 500., 1000., 2500., 5000., 10000.]}
gsmodel = GridSearchCV(rreg, param_grid, scoring='neg_mean_squared_error', cv=5)
gsmodel.fit(X_train, y_train)
print("MSE on training data:", mean_squared_error(y_train, gsmodel.predict(X_train)))
print("MSE on test data:", mean_squared_error(y_test, gsmodel.predict(X_test)))
print("R^2 on training data:", r2_score(y_train, gsmodel.predict(X_train)))
print("R^2 on test data:", r2_score(y_test, gsmodel.predict(X_test)))
print("-----------------------------------------")
print("######## Ridge Regression with autofeat")
rreg2 = Ridge()
param_grid2 = {"alpha": [0.00001, 0.0001, 0.001, 0.01, 0.1, 1., 2.5, 5., 10., 25., 50., 100., 250., 500., 1000., 2500., 5000., 10000.]}
gsmodel2 = GridSearchCV(rreg2, param_grid2, scoring='neg_mean_squared_error', cv=5)
gsmodel2.fit(X_train_tr, y_train)
print("MSE on training data:", mean_squared_error(y_train, gsmodel2.predict(X_train_tr)))
print("MSE on test data:", mean_squared_error(y_test, gsmodel2.predict(X_test_tr)))
print("R^2 on training data:", r2_score(y_train, gsmodel2.predict(X_train_tr)))
print("R^2 on test data:", r2_score(y_test, gsmodel2.predict(X_test_tr)))
# Out:
# [AutoFeat] The 2 step feature engineering process could generate up to 69006 features.
# [AutoFeat] With 40948 data points this new feature matrix would use about 11.30 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng] Generated 146 transformed features from 53 original features - done.
# [feateng] Step 2: first combination of features
# [feateng] Generated 14689 feature combinations from 19701 original feature tuples - done.
# [feateng] Generated altogether 19884 new features in 2 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 5115 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 121 features after 5 feature selection runs
# [featsel] 107 features after correlation filtering
# [featsel] 57 features after noise filtering
# [AutoFeat] Computing 56 new features.
# [AutoFeat]    56/   56 new features ...done.
# [AutoFeat] Final dataframe with 109 feature columns (56 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# 8.43011940729807
# -17065.782193 * x002**3*x030
# -14723.858437 * sqrt(x001)*sqrt(x004)
# -996.140514 * sqrt(x007)*sqrt(x030)
# 446.555563 * x002*sqrt(x036)
# -249.281249 * sqrt(x009)*log(x003)
# -196.455250 * x002*sqrt(x034)
# 123.509502 * x036**3/x003
# 54.064044 * x034
# -25.005000 * sqrt(x019)*log(x003)
# -22.578489 * x030**2/x038
# 18.706470 * sqrt(x034)*log(x038)
# -16.892205 * sqrt(x030)*log(x038)
# -14.430569 * sqrt(x011)*log(x038)
# 9.996396 * sqrt(x031)*log(x038)
# -8.001406 * sqrt(x036)*log(x003)
# 6.185842 * x051/x038
# -5.501872 * x036**2/x038
# 1.359927 * Abs(x033)/x038
# 1.355325 * log(x036)
# -1.247907 * x027/x003
# 1.221817 * x033/x038
# 1.204603 * Abs(x027)/x003
# 1.035255 * x030/x038
# -0.943472 * x009/x038
# -0.621142 * exp(x002)*log(x038)
# 0.335161 * x030/x003
# 0.296528 * Abs(x026)/x003
# 0.294152 * x036**2/x003
# -0.201370 * x032/x003
# -0.178648 * x019/x038
# 0.143129 * x034/x036
# 0.109741 * x036/x003
# 0.074602 * sqrt(x051)/x038
# 0.059836 * sqrt(x044)/x038
# 0.056731 * x031/x036
# -0.055075 * x036/x038
# 0.048814 * Abs(x033)/x003
# 0.046934 * sqrt(x049)/x038
# 0.044350 * sqrt(x041)/x038
# 0.043402 * sqrt(x050)/x038
# -0.032373 * sqrt(x034)/x038
# -0.020960 * x034/x038
# 0.018967 * 1/sqrt(x038)
# 0.010499 * x008/x003
# 0.008392 * sqrt(x018)/x038
# 0.006786 * sqrt(x003)/x038
# -0.004832 * sqrt(x031)/x038
# 0.001062 * sqrt(x017)/x003
# 0.000884 * sqrt(x035)/x038
# -0.000853 * x002**2/x003
# -0.000705 * sqrt(x034)/x003
# -0.000265 * x001/x003
# -0.000252 * sqrt(x031)/x003
# -0.000183 * sqrt(x023)/x036
# 0.000118 * x002/x038
# [AutoFeat] Final score: 0.3548
# [AutoFeat] Computing 56 new features.
# [AutoFeat]    56/   56 new features ...done.
# ######## Ridge Regression without autofeat
# MSE on training data: 1244.323219124833
# MSE on test data: 1287.9409015626095
# R^2 on training data: 0.012333524273500984
# R^2 on test data: 0.008938297905737969
# -----------------------------------------
# ######## Ridge Regression with autofeat
# /Users/mikhailboyko/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.21332e-18): result may not be accurate.
#   overwrite_a=True).T
# /Users/mikhailboyko/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=9.4771e-19): result may not be accurate.
#   overwrite_a=True).T
# /Users/mikhailboyko/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.03046e-18): result may not be accurate.
#   overwrite_a=True).T
# /Users/mikhailboyko/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.16899e-18): result may not be accurate.
#   overwrite_a=True).T
# /Users/mikhailboyko/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.27102e-18): result may not be accurate.
#   overwrite_a=True).T
# /Users/mikhailboyko/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=9.50368e-18): result may not be accurate.
#   overwrite_a=True).T
# /Users/mikhailboyko/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=7.77463e-18): result may not be accurate.
#   overwrite_a=True).T
# /Users/mikhailboyko/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=8.2162e-18): result may not be accurate.
#   overwrite_a=True).T
# /Users/mikhailboyko/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=9.57391e-18): result may not be accurate.
#   overwrite_a=True).T
# /Users/mikhailboyko/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=1.08171e-17): result may not be accurate.
#   overwrite_a=True).T
# /Users/mikhailboyko/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=9.02558e-17): result may not be accurate.
#   overwrite_a=True).T
# /Users/mikhailboyko/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=8.17957e-17): result may not be accurate.
#   overwrite_a=True).T
# /Users/mikhailboyko/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=7.97472e-17): result may not be accurate.
#   overwrite_a=True).T
# /Users/mikhailboyko/Library/Python/3.7/lib/python/site-packages/sklearn/linear_model/_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=9.2458e-17): result may not be accurate.
#   overwrite_a=True).T
# MSE on training data: 821.8635438885137
# MSE on test data: 890.2018449816429
# R^2 on training data: 0.3476557718730272
# R^2 on test data: 0.31499577765985587
